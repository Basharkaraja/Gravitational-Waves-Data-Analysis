# %% [markdown]
# ##**GW151226 Characteristics:**
#
# Nature: Black hole binary systemS.
#
# Mass1: 14.2(+8.3,-3.7) $M_{\odot}%s$
#
# Mass2: 7.5(+2.3,-2.3) $M_{\odot}%s$
#
# Distance from Earth: 440(+180,-190) Mpc
#
# **Note**:
#
#   Mpc = Megaparsecs
#
#   $M_{\odot}%s$= Solar Mas
#
#  1 solar mass = mass of our son
#
#  1 Mpc = 3261563.7769443 Light years

# %%
import sys
# !{sys.executable} -m pip install pycbc ligo-common --no-cache-dir
# Out:
# Collecting pycbc
#   Downloading PyCBC-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 60.9 MB/s eta 0:00:00
# Collecting ligo-common
#   Downloading ligo_common-1.0.3-py2.py3-none-any.whl (2.0 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pycbc) (1.23.5)
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.10/dist-packages (from pycbc) (3.0.6)
# Requirement already satisfied: scipy>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pycbc) (1.11.4)
# Requirement already satisfied: astropy!=4.0.5,!=4.2.1,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from pycbc) (5.3.4)
# Requirement already satisfied: matplotlib>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from pycbc) (3.7.1)
# Collecting mpld3>=0.3 (from pycbc)
#   Downloading mpld3-0.5.9-py3-none-any.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.2/201.2 kB 99.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pycbc) (9.4.0)
# Requirement already satisfied: h5py!=3.7.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from pycbc) (3.9.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from pycbc) (3.1.2)
# Collecting Mako>=1.0.1 (from pycbc)
#   Downloading Mako-1.3.0-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 119.5 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from pycbc) (4.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pycbc) (4.66.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from pycbc) (67.7.2)
# Collecting gwdatafind (from pycbc)
#   Downloading gwdatafind-1.2.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 105.2 MB/s eta 0:00:00
# Collecting pegasus-wms.api>=5.0.6 (from pycbc)
#   Downloading pegasus-wms.api-5.0.6.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 136.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting python-ligo-lw>=1.7.0 (from pycbc)
#   Downloading python-ligo-lw-1.8.3.tar.gz (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 75.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting ligo-segments (from pycbc)
#   Downloading ligo-segments-1.4.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 121.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting lalsuite!=7.2 (from pycbc)
#   Downloading lalsuite-7.21-cp310-cp310-manylinux_2_28_x86_64.whl (43.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 145.1 MB/s eta 0:00:00
# Collecting lscsoft-glue>=1.59.3 (from pycbc)
#   Downloading lscsoft-glue-3.0.1.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 174.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pykerr (from pycbc)
#   Downloading pykerr-0.1.0-py3-none-any.whl (48.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 MB 146.5 MB/s eta 0:00:00
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (2.0.1.1)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy!=4.0.5,!=4.2.1,>=2.0.3->pycbc) (23.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.6.0->pycbc) (2.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from lalsuite!=7.2->pycbc) (2.8.2)
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.10/dist-packages (from lscsoft-glue>=1.59.3->pycbc) (23.3.0)
# Collecting pyRXP (from lscsoft-glue>=1.59.3->pycbc)
#   Downloading pyRXP-3.0.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (298 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.1/298.1 kB 173.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from lscsoft-glue>=1.59.3->pycbc) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako>=1.0.1->pycbc) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->pycbc) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->pycbc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->pycbc) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->pycbc) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5.1->pycbc) (3.1.1)
# Collecting pegasus-wms.common (from pegasus-wms.api>=5.0.6->pycbc)
#   Downloading pegasus-wms.common-5.0.6.tar.gz (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 170.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting igwn-auth-utils>=0.3.1 (from gwdatafind->pycbc)
#   Downloading igwn_auth_utils-1.1.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: cryptography>=2.3 in /usr/local/lib/python3.10/dist-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (41.0.7)
# Requirement already satisfied: requests>=2.14 in /usr/local/lib/python3.10/dist-packages (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.31.0)
# Collecting safe-netrc>=1.0.0 (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc)
#   Downloading safe_netrc-1.0.1-py3-none-any.whl (10 kB)
# Collecting scitokens>=1.7.0 (from igwn-auth-utils>=0.3.1->gwdatafind->pycbc)
#   Downloading scitokens-1.8.1-py3-none-any.whl (31 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.14->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2023.11.17)
# Requirement already satisfied: PyJWT>=1.6.1 in /usr/lib/python3/dist-packages (from scitokens>=1.7.0->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.3->igwn-auth-utils>=0.3.1->gwdatafind->pycbc) (2.21)
# Building wheels for collected packages: lscsoft-glue, pegasus-wms.api, python-ligo-lw, ligo-segments, pegasus-wms.common
#   Building wheel for lscsoft-glue (pyproject.toml) ... done
#   Created wheel for lscsoft-glue: filename=lscsoft_glue-3.0.1-cp310-cp310-linux_x86_64.whl size=246712 sha256=d71a660d256c406670c690fd4598bd80c09e1949328072f37272c100ac5de96b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pbirkojk/wheels/ed/27/c6/e616150ac6c17c01597c9905efc771d8ef22e591346711f08a
#   Building wheel for pegasus-wms.api (pyproject.toml) ... done
#   Created wheel for pegasus-wms.api: filename=pegasus_wms.api-5.0.6-py3-none-any.whl size=50065 sha256=3882e27daed41b8781c02d6c5ea98c749869025d3b0f7a49c43da230b6124980
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pbirkojk/wheels/4f/76/84/81fd82d7a107da5e1efe55878728c0c2a1de8d50c907ac8851
#   Building wheel for python-ligo-lw (setup.py) ... done
#   Created wheel for python-ligo-lw: filename=python_ligo_lw-1.8.3-cp310-cp310-linux_x86_64.whl size=155116 sha256=0fdf84a238ae388d16ab1c4ccd6d57fd9474cd4f88cdf73597d940b4fa67465c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pbirkojk/wheels/56/47/e8/75b3e1cf390f9b408944a7914964f73eb932b0cfb739c9ed1d
#   Building wheel for ligo-segments (setup.py) ... done
#   Created wheel for ligo-segments: filename=ligo_segments-1.4.0-cp310-cp310-linux_x86_64.whl size=99255 sha256=4579695c1b80a0962da45f94eb31ff02ed3ecf640154c92e77e5851c4cc57249
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pbirkojk/wheels/6d/48/d1/3466977be4e41ba57f92ad0d5619f083df43cf319a151c4e06
#   Building wheel for pegasus-wms.common (pyproject.toml) ... done
#   Created wheel for pegasus-wms.common: filename=pegasus_wms.common-5.0.6-py3-none-any.whl size=50816 sha256=061ca958e27f623a8e6883d66c97f4dbbe5c45e78243dea029038b9a4856aefb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pbirkojk/wheels/0b/62/b8/c751cda2a8e09c812fe9dbc36abbe8980bd29576d9e449b37a
# Successfully built lscsoft-glue pegasus-wms.api python-ligo-lw ligo-segments pegasus-wms.common
# Installing collected packages: ligo-common, safe-netrc, pyRXP, pegasus-wms.common, Mako, ligo-segments, pykerr, pegasus-wms.api, scitokens, mpld3, lscsoft-glue, igwn-auth-utils, python-ligo-lw, lalsuite, gwdatafind, pycbc
# Successfully installed Mako-1.3.0 gwdatafind-1.2.0 igwn-auth-utils-1.1.0 lalsuite-7.21 ligo-common-1.0.3 ligo-segments-1.4.0 lscsoft-glue-3.0.1 mpld3-0.5.9 pegasus-wms.api-5.0.6 pegasus-wms.common-5.0.6 pyRXP-3.0.1 pycbc-2.4.0 pykerr-0.1.0 python-ligo-lw-1.8.3 safe-netrc-1.0.1 scitokens-1.8.1

# %% [markdown]
# ## **Matched Filtering**
#
# Explanation about the model used and its parameters can be found in GW150914-H1 jupyter notebook

# %% [markdown]
# # **Filtering the data**

# %%
import pylab
from pycbc.catalog import Merger
from pycbc.filter import resample_to_delta_t, highpass
from pycbc.waveform import get_td_waveform


merger_system = Merger("GW151226")

# Get the data from the Hanford detector
strain_data = merger_system.strain('H1')

# Remove the low frequency content and downsample the data to 2048Hz
strain_data = resample_to_delta_t(highpass(strain_data, 15.0), 1.0/2048)

pylab.plot(strain_data.sample_times, strain_data)
pylab.xlabel('GPS Time(s)')
pylab.title('GW151226-H1 data')
pylab.show()



# GW151226
# Out:
# /usr/local/lib/python3.10/dist-packages/pycbc/types/array.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(True)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal as _lal

# %% [markdown]
# #### filter wraparound
#
# due to highpass filtering and resampling, spikes at the boundaries of our data have been generated. To avoid this we trim the ends of the data sufficiently to ensure that they do not wraparound the input. We will enforce this requirement in all steps of our filtering, and this shall have no impact on the accuracy of our model.

# %%
# Remove 2 seconds of data from both the beginning and end
cropped = strain_data.crop(2, 2)

pylab.plot(cropped.sample_times, cropped)
pylab.xlabel('GPS Time(s)')
pylab.title('GW151226-H1 Cropeed signal')
pylab.show()

# %% [markdown]
# #### calculate the power spectral density
#
# Optimal matched filtering requires weighting the frequency components of the potential signal and data by the noise amplitude. We can view this as filtering the data with the time series equivelant of 1 / PSD. To ensure that we can control how much applying this filter to the data, we window the time domain equivelant of the PSD to a specific length.

# %%
from pycbc.psd import interpolate, inverse_spectrum_truncation
# Estimate the power spectral density
# We use 4 second samples.
psd = cropped.psd(4)

# interpolate the PSD to match our data
# and then limit the filter length of 1 / PSD. After this, we can
# directly use this PSD to filter the data in a controlled manner

psd = interpolate(psd, cropped.delta_f)

# 1/PSD will now act as a filter with an effective length of 4 seconds
psd = inverse_spectrum_truncation(psd, int(4 * cropped.sample_rate),
                                  low_frequency_cutoff=15) # the cutoff is to avoid low values as we highpassed the data before at threshold 15Hz

pylab.loglog(psd.sample_frequencies, psd)
pylab.ylabel('$Strain^2 / Hz$')
pylab.title(' GW151226-H1 PSD ')
pylab.xlabel('Frequency (Hz)')
pylab.xlim(30, 1024)
# Out:
# (30, 1024)

# %% [markdown]
# #**Creating the simulated signal**
#
# In general, matched filtering involves laying the potential signal over your data and integrating (after weighting frequencies correctly). If there is a signal in the data that aligns with your 'simulated', you will get a large value when integrated over.
#
# Since we already know our merger system, we then have the key parameters discussed above, and we'll use them now to build the model to simulate similar conditions to our system.
#
# **Note**: since the masses the two compononets in the binary systems overlaps in the range of uncertainties we will be assuming equaly masses for both bodies. If this have shown some in accuracies we will adjust it, but in principal it shouldn't

# %%
m = 10 # Solar masses
w_plus, w_cross = get_td_waveform(approximant="SEOBNRv4_opt",
                     mass1=m,
                     mass2=m,
                     delta_t=cropped.delta_t,
                     f_lower=20)

#  resize to match our data
w_plus.resize(len(cropped))

# The waveform begins at the start of the vector, so if we want the
# SNR time series to correspond to the approximate merger location
# we need to shift the data so that the merger is approximately at the
# first bin of the data.

# This function rotates the vector by a fixed amount of time.
# Note that time stamps are not affected, but the true
# position in the vector is.

# In our simulation we will be taking the plus polarization into account and see how accurate the results will be.
simulated = w_plus.cyclic_time_shift(w_plus.start_time)
pylab.plot(simulated)
pylab.title('Simulated GW151226-H1 peak')
pylab.show()

# %% [markdown]
# #### calculating the signal-to-noise time series
#
# In this section we will calculate the signal-to-noise time series for our simulated.

# %%
from pycbc.filter import matched_filter
import numpy

snr = matched_filter(simulated, cropped,
                     psd=psd, low_frequency_cutoff=20)


# remove 4 seconds at the beginning and 4 seconds at the end to eliminate time corrupted by the simulated filter and psd filter:
snr = snr.crop(4 + 4, 4)
# plot the results:
pylab.figure(figsize=[10, 4])
pylab.plot(snr.sample_times, abs(snr)) # since the Matched filter returns complex number, we will take their real part to maximize over the phase signal
pylab.ylabel('Signal-to-noise')
pylab.title('signal to noise ratio as a function of time')
pylab.xlabel('GPS Time (s)')
pylab.show()

# EXTRACT THE CHIRPING PEAK OF THE SIMULATED SIGNAL AND ITS TIME OF OCCURENCE
peak = abs(snr).numpy().argmax()
snrp = snr[peak]
time = snr.sample_times[peak]

# %% [markdown]
# # **Aligning and Subtracting the Proposed Signal**
#
#
# After getrting our simulated chirping peak, we will use it to align our simulation to the original data of GW151226.

# %%
from pycbc.filter import sigma

# Shift our simulation to the time of the Chirping peak
dt = time - cropped.start_time
cohered = simulated.cyclic_time_shift(dt)

# scale the simulation to get SNR= 1 in this data
cohered /= sigma(cohered, psd=psd, low_frequency_cutoff=20.0)

# Scale the simulated amplitude and phase to the peak value
cohered = (cohered.to_frequencyseries() * snrp).to_timeseries()
cohered.start_time = cropped.start_time

# %% [markdown]
# #### **Overlap plot of the similation and the original data**
#
# As we did in our analysis of the GW190817 and GW170817 systems, we will whiten both, the simulated signal and the original data, to highlight noise and then bandpass them to get the relavent frequency range that is contributing to the merger event only(30-300Hz).

# %%
# whiten and band pass the data and simulation:
white_data = (cropped.to_frequencyseries() / psd**0.5).to_timeseries() # whiten the original data

# whiten the simulated signal
tapered = cohered.highpass_fir(30, 512, remove_corrupted=False)
white_simulated = (tapered.to_frequencyseries() / psd**0.5).to_timeseries()

white_data = white_data.highpass_fir(30., 512).lowpass_fir(300, 512) # bandpas original data
white_simulated = white_simulated.highpass_fir(30, 512).lowpass_fir(300, 512)  # band pass simulated data

# Select the time around the merger
white_data = white_data.time_slice(merger_system.time-.2, merger_system.time+.1) # whiten original data
white_simulated = white_simulated.time_slice(merger_system.time-.2, merger_system.time+.1) # whiten simulated data

pylab.figure(figsize=[15, 3])
pylab.plot(white_data.sample_times, white_data, label="Original GW151226H-H1 signal")
pylab.plot(white_simulated.sample_times, white_simulated, label="simulated signal")
pylab.title('GW151226-H1 whitened and band passedsignals')
pylab.xlabel('GPS time(s)')
pylab.legend()
pylab.show()

# %% [markdown]
# Notice that a considerable alignment between our simulation and the original data can bee seen at the time of the merger, and all that is left now is to extract our signal by subtracting the simulated chirping peak from the original data.
#
# #### **Subtracting the signal from the data and spctrogram**
#
# We will plot both the spectrogram of the original data before and after the  subtraction by our simulated signal to see how accurate our simulation is.

# %%
subtracted = cropped - cohered
# sim_chirping= cropped - subtracted
# Plot the original data and the subtracted signal data

for data, title in [(cropped, 'Original GW151226-H1 Data'),
                    (subtracted, 'Signal Subtracted from GW190814-H1 Data')]:

    t, f, p = data.whiten(4, 4).qtransform(.001,
                                                  logfsteps=100,
                                                  qrange=(8, 8),
                                                  frange=(20, 512))
    pylab.figure(figsize=[15, 3])
    pylab.title(title)
    pylab.pcolormesh(t, f, p**0.5, vmin=1, vmax=6)
    pylab.colorbar()
    pylab.yscale('log')
    pylab.xlabel('Time (s)')
    pylab.ylabel('Frequency (Hz)')
    pylab.xlim(merger_system.time - 2, merger_system.time + 1)
    pylab.show()

# %% [markdown]
# Notice that after the subtraction of the data from our simulated signal, the chirping peak have completely disappeared and is no longer visible. This is an indication that the chirping peak simulated by our model is very close to the initial data and we have succefully simulated a merging event similar to that of GW190814-H1
